# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
# Set paths to input and output
INPUT = 'input_for_cnn_star_w_psfs_defocused.h5'
OUTPUT = 'cnn_output_star_def.h5'

# Iterate over all datasets in the input file and transform them using the CNN
with h5py.File(INPUT, 'r') as h5fi, h5py.File(OUTPUT, 'w') as h5fo:
    images = np.array(h5fi['inputs'])    
    transformed = np.random.random(images.shape) #model.predict(images)
    h5fo.create_dataset('outputs', data=transformed)
